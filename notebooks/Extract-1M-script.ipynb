# %%
import pandas as pd

# %%
df = pd.read_csv('..\\row\\btcusd_1-min_data.csv')
last_milion = df.tail(1_000_000)
last_milion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 6565458 to 7565457
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   Timestamp  1000000 non-null  float64
#  1   Open       1000000 non-null  float64
#  2   High       1000000 non-null  float64
#  3   Low        1000000 non-null  float64
#  4   Close      1000000 non-null  float64
#  5   Volume     1000000 non-null  float64
# dtypes: float64(6)
# memory usage: 45.8 MB

# %%
last_milion.to_csv('..\\row\\btcusd_1m_1M_data.csv', index=False)
